# %% [markdown]
# # QualityPhys - Camera Remote Vital Signs Estimator (CRVSE) Project
#
# ## Notebook P3-11: HR EfficientPhys Training (screening pass - final architecture)
#
# ### What this notebook does
# Trains EfficientPhys (efficient temporal-shift CNN, Liu et al., WACV 2023) - the TS-CAN / DeepPhys family - as the LAST architecture in the screen-then-tune plan. This family is efficient, motion-robust (temporal-shift design), and the most on-device / app-relevant. Same pipeline as NB_P3_08-11: committed loader with multi-clip sampling, subject-wise split, temporal-rescale + hflip augmentation, cardiac_sqi soft-weighting, and the honest per-dataset / resting / Bland-Altman evaluation. Compared against PhysNet (val HR MAE ~8).
#
# ### EfficientPhys notes
# - Repo: ubicomplab/rPPG-Toolbox (also contains TS_CAN, DeepPhys). Efficient CNN family - reliable on Kaggle, no fragile CUDA-kernel deps.
# - **This family predicts the BVP FIRST-DIFFERENCE** (it computes frame differences internally). So the pipeline is adapted: input is our clip reshaped to [B*T, C, H, W]; the loss trains against the DIFF of the target BVP; HR at eval is the spectral peak of the diff-output (the derivative preserves the fundamental frequency); and the waveform overlays integrate (cumsum) the prediction back to a pulse for visual comparison.
# - Hyperparameters: sane defaults (Adam, lr 1e-3, cosine, 30 epochs).
#
# ### Implementation risks (read before running)
# EfficientPhys's constructor args (frame_depth / img_size) and its internal temporal-shift reshaping can't be verified from here, so **Section 5 sanity is the gate** - if `build_efficientphys()` or `ep_forward` errors, paste the printed model listing + the error and it will be pinned. No frames are rendered.

# %% [markdown]
# ## 1. Imports & Config (+ clone rPPG-Toolbox)

# %%
import os, sys, time, random, glob, importlib
from pathlib import Path
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import h5py
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# Clone rPPG-Toolbox (has EfficientPhys / TS_CAN / DeepPhys). No fragile deps.
if not os.path.exists('rPPG-Toolbox'):
    os.system('git clone --depth 1 https://github.com/ubicomplab/rPPG-Toolbox')
sys.path.append('rPPG-Toolbox')
for d in glob.glob('rPPG-Toolbox/**/', recursive=True):
    sys.path.append(d)

DATA_DIR = Path('/kaggle/input/datasets/cezarytubacki/phase3-hr-train-dataset')

# Auto-discover H5 files in the dataset
H5_FILES = sorted([f.name for f in DATA_DIR.glob('*.h5')])

CLIP_LEN = 160
IMG_SIZE = 72
BATCH_SIZE = 8
CLIPS_PER_REC = 2
NUM_WORKERS = 2
VAL_FRAC = 0.2
SEED = 42

AUG_PROB = 0.5
SPEED_MIN, SPEED_MAX = 0.7, 2.0
SQI_FLOOR = 0.05

LR = 1e-3
WEIGHT_DECAY = 1e-4
EPOCHS = 30
LAMBDA_FREQ = 0.2
HR_LOW, HR_HIGH = 0.66, 3.0

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(SEED); np.random.seed(SEED); random.seed(SEED)
torch.backends.cudnn.benchmark = True
print('device:', device, '| DATA_DIR:', DATA_DIR)
print('files present:', [fn for fn in H5_FILES if (DATA_DIR / fn).exists()])
# Out:
# Cloning into 'rPPG-Toolbox'...
# Updating files: 100% (327/327), done.
# device: cuda | DATA_DIR: /kaggle/input/datasets/cezarytubacki/phase3-hr-train-dataset
# files present: ['dlcn_phase3.h5', 'mcd_phase3.h5', 'ubfc_rppg_phase3.h5']

# %% [markdown]
# ## 2. Data Loader - index, subject-wise split, dataset (multi-clip sampling)

# %%
def build_index(data_dir, h5_files, sqi_floor=SQI_FLOOR, clip_len=CLIP_LEN):
    index = []
    for fn in h5_files:
        path = Path(data_dir) / fn
        if not path.exists():
            print('missing', path); continue
        with h5py.File(path, 'r') as f:
            for name in f.keys():
                a = f[name].attrs
                if not bool(a.get('usable', True)):
                    continue
                if float(a.get('cardiac_sqi', 0.0)) < sqi_floor:
                    continue
                n = int(a['n_frames'])
                if n < clip_len:
                    continue
                index.append(dict(file=fn, group=name, dataset=str(a.get('dataset', fn)),
                                  subject=str(a.get('subject_id', name)), n_frames=n,
                                  fps=float(a.get('fps', 30.0)), sqi=float(a.get('cardiac_sqi', 0.0))))
    return index


def subject_split(index, val_frac=VAL_FRAC, seed=SEED):
    subjects = sorted({r['dataset'] + '/' + r['subject'] for r in index})
    rng = random.Random(seed); rng.shuffle(subjects)
    n_val = max(1, int(round(len(subjects) * val_frac)))
    val_subj = set(subjects[:n_val])
    tr = [r for r in index if (r['dataset'] + '/' + r['subject']) not in val_subj]
    va = [r for r in index if (r['dataset'] + '/' + r['subject']) in val_subj]
    return tr, va, val_subj


def compute_hr(bvp, fps, low=HR_LOW, high=HR_HIGH):
    x = np.asarray(bvp, dtype=np.float64); x = x - x.mean()
    if x.size < 16 or not np.all(np.isfinite(x)) or np.std(x) < 1e-9:
        return np.nan
    p = np.abs(np.fft.rfft(x * np.hanning(x.size))) ** 2
    fr = np.fft.rfftfreq(x.size, 1.0 / fps)
    b = (fr >= low) & (fr <= high)
    if not b.any() or p[b].sum() <= 0:
        return np.nan
    return float(fr[b][int(np.argmax(p[b]))] * 60.0)


class RPPGClipDataset(Dataset):
    def __init__(self, index, data_dir, clip_len=CLIP_LEN, augment=False, clips_per_rec=1,
                 aug_prob=AUG_PROB, speed_range=(SPEED_MIN, SPEED_MAX), seed=SEED):
        self.index = index; self.data_dir = Path(data_dir); self.clip_len = clip_len
        self.augment = augment; self.clips_per_rec = clips_per_rec
        self.aug_prob = aug_prob; self.speed_range = speed_range
        self._files = {}; self._rng = np.random.default_rng(seed)

    def _h5(self, fn):
        h = self._files.get(fn)
        if h is None:
            h = h5py.File(self.data_dir / fn, 'r'); self._files[fn] = h
        return h

    def __len__(self):
        return len(self.index) * self.clips_per_rec

    def __getitem__(self, i):
        rec = self.index[i % len(self.index)]; g = self._h5(rec['file'])[rec['group']]
        n, T = rec['n_frames'], self.clip_len
        if self.augment and self._rng.random() < self.aug_prob:
            src_len = int(round(T * float(self._rng.uniform(*self.speed_range))))
            src_len = max(T, min(src_len, n))
        else:
            src_len = T
        max_start = n - src_len
        start = int(self._rng.integers(0, max_start + 1)) if (self.augment and max_start > 0) else max_start // 2
        frames_src = g['frames'][start:start + src_len].astype(np.float32)
        bvp_src = g['bvp'][start:start + src_len].astype(np.float32)
        pos = np.linspace(0, src_len - 1, T)
        frames = frames_src[np.rint(pos).astype(int)]
        bvp = np.interp(pos, np.arange(src_len), bvp_src)
        hr_bpm = compute_hr(bvp, rec['fps'])
        if self.augment and self._rng.random() < 0.5:
            frames = frames[:, :, ::-1, :]
        m = frames.mean(axis=(0, 1, 2), keepdims=True); sd = frames.std(axis=(0, 1, 2), keepdims=True) + 1e-6
        frames = np.ascontiguousarray((frames - m) / sd)
        frames = torch.from_numpy(frames).permute(3, 0, 1, 2).float()
        bvp = (bvp - bvp.mean()) / (bvp.std() + 1e-6)
        bvp = torch.from_numpy(bvp.astype(np.float32))
        return dict(frames=frames, bvp=bvp,
                    hr=torch.tensor(hr_bpm if np.isfinite(hr_bpm) else 0.0, dtype=torch.float32),
                    sqi=torch.tensor(rec['sqi'], dtype=torch.float32),
                    fps=torch.tensor(rec['fps'], dtype=torch.float32),
                    dataset=rec['dataset'])


def worker_init_fn(worker_id):
    info = torch.utils.data.get_worker_info(); ds = info.dataset
    ds._files = {}; ds._rng = np.random.default_rng(SEED + 1000 * (worker_id + 1) + int(info.seed % 100000))


def make_loader(index, augment, clips_per_rec=1):
    ds = RPPGClipDataset(index, DATA_DIR, augment=augment, clips_per_rec=clips_per_rec)
    return DataLoader(ds, batch_size=BATCH_SIZE, shuffle=augment, num_workers=NUM_WORKERS,
                      worker_init_fn=worker_init_fn, pin_memory=True, drop_last=augment,
                      persistent_workers=(NUM_WORKERS > 0))

# %% [markdown]
# ## 3. Model - EfficientPhys (rPPG-Toolbox)

# %%
# Auto-discover EfficientPhys.
EPClass = None
for modname in ['neural_methods.model.EfficientPhys', 'model.EfficientPhys', 'EfficientPhys']:
    try:
        m = importlib.import_module(modname)
        EPClass = getattr(m, 'EfficientPhys')
        print('imported EfficientPhys from', modname)
        break
    except Exception as e:
        print('import', modname, 'failed:', repr(e))

if EPClass is None:
    print('EfficientPhys not found. Model files in repo:')
    for pyf in glob.glob('rPPG-Toolbox/**/model/**/*.py', recursive=True):
        print('   ', pyf)
    raise RuntimeError('Could not import EfficientPhys - paste this listing.')


def build_efficientphys():
    last = None
    for kw in [dict(frame_depth=CLIP_LEN, img_size=IMG_SIZE),
               dict(img_size=IMG_SIZE), dict(frame_depth=CLIP_LEN), dict()]:
        try:
            return EPClass(**kw)
        except Exception as e:
            last = e
    raise last


def ep_forward(model, x):
    '''EfficientPhys folds time into batch and diffs internally (count -1); we append one frame so the
    post-diff count = B*T stays divisible by frame_depth. Returns the diff-BVP [B,T]. fp32.'''
    B, C, T, H, W = x.shape
    xx = x.permute(0, 2, 1, 3, 4).reshape(B * T, C, H, W).contiguous().float()
    xx = torch.cat([xx, xx[-1:]], dim=0)          # +1 frame -> internal diff yields B*T (divisible by frame_depth)
    out = model(xx)
    out = out.reshape(B, -1)
    if out.shape[1] < T:
        out = F.pad(out, (0, T - out.shape[1]))
    return out[:, :T]


def diff_target(bvp):
    '''First-difference of the target BVP (EfficientPhys predicts the derivative), padded to length T.'''
    td = torch.zeros_like(bvp)
    td[:, 1:] = bvp[:, 1:] - bvp[:, :-1]
    return td
# Out:
# imported EfficientPhys from neural_methods.model.EfficientPhys

# %% [markdown]
# ## 4. Losses & Evaluation Functions

# %%
def neg_pearson(pred, target):
    pred = pred - pred.mean(dim=1, keepdim=True)
    target = target - target.mean(dim=1, keepdim=True)
    num = (pred * target).sum(dim=1)
    den = torch.sqrt((pred ** 2).sum(dim=1) * (target ** 2).sum(dim=1) + 1e-8)
    return 1.0 - num / (den + 1e-8)


def freq_loss(pred, target, fps=30.0, low=HR_LOW, high=HR_HIGH):
    pred = pred.float(); target = target.float()
    pred = pred - pred.mean(dim=1, keepdim=True)
    target = target - target.mean(dim=1, keepdim=True)
    Pp = torch.abs(torch.fft.rfft(pred, dim=1)) ** 2
    Pt = torch.abs(torch.fft.rfft(target, dim=1)) ** 2
    freqs = torch.fft.rfftfreq(pred.shape[1], 1.0 / fps).to(pred.device)
    band = (freqs >= low) & (freqs <= high)
    Pp = Pp[:, band]; Pt = Pt[:, band]
    Pp = Pp / (Pp.sum(dim=1, keepdim=True) + 1e-8)
    Pt = Pt / (Pt.sum(dim=1, keepdim=True) + 1e-8)
    return ((Pp - Pt) ** 2).sum(dim=1)


def hr_from_bvp(sig, fps, low=HR_LOW, high=HR_HIGH):
    x = np.asarray(sig, dtype=np.float64); x = x - x.mean()
    if x.std() < 1e-8:
        return np.nan
    p = np.abs(np.fft.rfft(x * np.hanning(len(x)))) ** 2
    f = np.fft.rfftfreq(len(x), 1.0 / fps)
    b = (f >= low) & (f <= high)
    if not b.any() or p[b].sum() <= 0:
        return np.nan
    return float(f[b][int(np.argmax(p[b]))] * 60.0)


@torch.no_grad()
def evaluate(model, loader, tag='val'):
    model.eval(); rows = []
    for batch in loader:
        frames = batch['frames'].to(device, non_blocking=True)
        pred = ep_forward(model, frames).float().cpu().numpy()   # diff-BVP; HR = its spectral peak
        hr_true = batch['hr'].numpy(); fps = batch['fps'].numpy(); ds = batch['dataset']
        for i in range(len(pred)):
            if not (40.0 <= hr_true[i] <= 180.0):
                continue
            hp = hr_from_bvp(pred[i], float(fps[i]))
            if np.isfinite(hp):
                rows.append((ds[i], float(hr_true[i]), hp))
    df = pd.DataFrame(rows, columns=['dataset', 'hr_true', 'hr_pred'])
    if len(df) == 0:
        print('  no valid eval clips'); return 1e9
    df['ae'] = (df.hr_pred - df.hr_true).abs()
    mae = float(df.ae.mean()); rmse = float(np.sqrt(((df.hr_pred - df.hr_true) ** 2).mean()))
    r = float(np.corrcoef(df.hr_true, df.hr_pred)[0, 1]) if len(df) > 2 else float('nan')
    print(f'  [{tag}] MAE {mae:.2f} | RMSE {rmse:.2f} | r {r:.3f} | n {len(df)}')
    print('   per-dataset MAE:', df.groupby('dataset')['ae'].mean().round(2).to_dict())
    rest = df[df.hr_true < 90]
    if len(rest):
        print(f'   resting <90bpm MAE {rest.ae.mean():.2f} (n {len(rest)})')
    return mae

# %% [markdown]
# ## 5. Sanity Check

# %%
index = build_index(DATA_DIR, H5_FILES)
print('usable recordings:', len(index), '| by dataset:', dict(Counter(r['dataset'] for r in index)))
train_idx, val_idx, val_subj = subject_split(index)
print('train recs:', len(train_idx), '| val recs:', len(val_idx), '| val subjects:', len(val_subj))

train_loader = make_loader(train_idx, augment=True, clips_per_rec=CLIPS_PER_REC)
val_loader = make_loader(val_idx, augment=False, clips_per_rec=1)
print('train clips/epoch:', len(train_loader.dataset), '| val clips:', len(val_loader.dataset))

model = build_efficientphys().to(device)
print('EfficientPhys params:', round(sum(p.numel() for p in model.parameters()) / 1e6, 2), 'M')

batch = next(iter(train_loader))
print('batch frames', tuple(batch['frames'].shape), '| bvp', tuple(batch['bvp'].shape))
with torch.no_grad():
    out = ep_forward(model, batch['frames'][:2].to(device))
print('model output', tuple(out.shape), '(expect [2,', CLIP_LEN, '])')
# Out:
# usable recordings: 2010 | by dataset: {'DLCN': 777, 'MCD': 1191, 'UBFC-rPPG': 42}
# train recs: 1585 | val recs: 425 | val subjects: 148
# train clips/epoch: 3170 | val clips: 425
# EfficientPhys params: 2.16 M
# batch frames (8, 3, 160, 72, 72) | bvp (8, 160)
# model output (2, 160) (expect [2, 160 ])

# %% [markdown]
# ## 6. Training

# %%
opt = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)

best = 1e9
for epoch in range(EPOCHS):
    model.train(); tot = 0.0; nb = 0; t0 = time.time()
    for batch in train_loader:
        frames = batch['frames'].to(device, non_blocking=True)
        bvp = batch['bvp'].to(device, non_blocking=True)
        sqi = batch['sqi'].to(device, non_blocking=True)
        opt.zero_grad(set_to_none=True)
        pred = ep_forward(model, frames)          # diff-BVP prediction
        target_d = diff_target(bvp)               # diff of target BVP
        per = neg_pearson(pred, target_d) + LAMBDA_FREQ * freq_loss(pred, target_d)
        w = sqi.clamp(min=1e-3)
        loss = (per * w).sum() / w.sum()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()
        tot += float(loss.item()); nb += 1
    sched.step()
    print(f'epoch {epoch + 1}/{EPOCHS} | train_loss {tot / max(nb, 1):.4f} | {time.time() - t0:.0f}s')
    mae = evaluate(model, val_loader)
    if mae < best:
        best = mae; torch.save(model.state_dict(), 'efficientphys_best.pt'); print('   * new best', round(best, 2))

torch.save(model.state_dict(), 'efficientphys_last.pt')
print('DONE | best val HR MAE:', round(best, 2), '(PhysNet baseline was 8.07)')
# Out:
# epoch 1/30 | train_loss 0.8648 | 422s
#   [val] MAE 20.83 | RMSE 34.31 | r 0.182 | n 425
#    per-dataset MAE: {'DLCN': 10.76, 'MCD': 29.39, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 22.88 (n 190)
#    * new best 20.83
# epoch 2/30 | train_loss 0.8218 | 407s
#   [val] MAE 19.87 | RMSE 33.57 | r 0.182 | n 425
#    per-dataset MAE: {'DLCN': 10.27, 'MCD': 27.98, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 21.86 (n 190)
#    * new best 19.87
# epoch 3/30 | train_loss 0.8110 | 381s
#   [val] MAE 21.82 | RMSE 36.44 | r 0.151 | n 425
#    per-dataset MAE: {'DLCN': 11.01, 'MCD': 31.01, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 24.79 (n 190)
# epoch 4/30 | train_loss 0.8109 | 383s
#   [val] MAE 19.46 | RMSE 33.24 | r 0.320 | n 425
#    per-dataset MAE: {'DLCN': 9.84, 'MCD': 27.58, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 20.91 (n 190)
#    * new best 19.46
# epoch 5/30 | train_loss 0.8106 | 383s
#   [val] MAE 17.52 | RMSE 30.77 | r 0.283 | n 425
#    per-dataset MAE: {'DLCN': 8.74, 'MCD': 24.95, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 18.43 (n 190)
#    * new best 17.52
# epoch 6/30 | train_loss 0.7993 | 389s
#   [val] MAE 19.62 | RMSE 32.98 | r 0.220 | n 425
#    per-dataset MAE: {'DLCN': 11.74, 'MCD': 26.42, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 20.37 (n 190)
# epoch 7/30 | train_loss 0.7934 | 391s
#   [val] MAE 18.49 | RMSE 32.93 | r 0.237 | n 425
#    per-dataset MAE: {'DLCN': 8.38, 'MCD': 26.97, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 20.72 (n 190)
# epoch 8/30 | train_loss 0.7967 | 385s
#   [val] MAE 17.32 | RMSE 30.61 | r 0.205 | n 425
#    per-dataset MAE: {'DLCN': 9.05, 'MCD': 24.3, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 18.98 (n 190)
#    * new best 17.32
# epoch 9/30 | train_loss 0.7961 | 387s
#   [val] MAE 19.93 | RMSE 34.65 | r 0.186 | n 425
#    per-dataset MAE: {'DLCN': 8.5, 'MCD': 29.49, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 23.31 (n 190)
# epoch 10/30 | train_loss 0.7815 | 387s
#   [val] MAE 16.78 | RMSE 30.06 | r 0.286 | n 425
#    per-dataset MAE: {'DLCN': 7.09, 'MCD': 24.91, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 17.36 (n 190)
#    * new best 16.78
# epoch 11/30 | train_loss 0.7810 | 382s
#   [val] MAE 15.81 | RMSE 28.51 | r 0.325 | n 425
#    per-dataset MAE: {'DLCN': 5.75, 'MCD': 24.2, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.98 (n 190)
#    * new best 15.81
# epoch 12/30 | train_loss 0.7827 | 382s
#   [val] MAE 15.85 | RMSE 27.94 | r 0.319 | n 425
#    per-dataset MAE: {'DLCN': 5.07, 'MCD': 24.75, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 16.42 (n 190)
# epoch 13/30 | train_loss 0.7769 | 385s
#   [val] MAE 17.82 | RMSE 30.93 | r 0.241 | n 425
#    per-dataset MAE: {'DLCN': 6.05, 'MCD': 27.63, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 18.86 (n 190)
# epoch 14/30 | train_loss 0.7735 | 381s
#   [val] MAE 16.49 | RMSE 29.16 | r 0.328 | n 425
#    per-dataset MAE: {'DLCN': 8.93, 'MCD': 22.94, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 17.64 (n 190)
# epoch 15/30 | train_loss 0.7730 | 384s
#   [val] MAE 15.67 | RMSE 28.79 | r 0.325 | n 425
#    per-dataset MAE: {'DLCN': 5.81, 'MCD': 23.9, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.41 (n 190)
#    * new best 15.67
# epoch 16/30 | train_loss 0.7708 | 385s
#   [val] MAE 15.53 | RMSE 27.80 | r 0.349 | n 425
#    per-dataset MAE: {'DLCN': 5.69, 'MCD': 23.75, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.09 (n 190)
#    * new best 15.53
# epoch 17/30 | train_loss 0.7714 | 387s
#   [val] MAE 15.54 | RMSE 28.91 | r 0.302 | n 425
#    per-dataset MAE: {'DLCN': 5.07, 'MCD': 24.25, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.14 (n 190)
# epoch 18/30 | train_loss 0.7683 | 386s
#   [val] MAE 16.96 | RMSE 30.93 | r 0.282 | n 425
#    per-dataset MAE: {'DLCN': 6.42, 'MCD': 25.76, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 18.07 (n 190)
# epoch 19/30 | train_loss 0.7676 | 384s
#   [val] MAE 15.74 | RMSE 29.07 | r 0.344 | n 425
#    per-dataset MAE: {'DLCN': 6.3, 'MCD': 23.65, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.64 (n 190)
# epoch 20/30 | train_loss 0.7618 | 386s
#   [val] MAE 14.21 | RMSE 26.51 | r 0.424 | n 425
#    per-dataset MAE: {'DLCN': 4.04, 'MCD': 22.59, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 14.66 (n 190)
#    * new best 14.21
# epoch 21/30 | train_loss 0.7602 | 384s
#   [val] MAE 14.73 | RMSE 27.90 | r 0.357 | n 425
#    per-dataset MAE: {'DLCN': 4.28, 'MCD': 23.34, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 16.13 (n 190)
# epoch 22/30 | train_loss 0.7567 | 387s
#   [val] MAE 14.63 | RMSE 27.70 | r 0.309 | n 425
#    per-dataset MAE: {'DLCN': 5.2, 'MCD': 22.44, 'UBFC-rPPG': 4.19}
#    resting <90bpm MAE 15.73 (n 190)
# epoch 23/30 | train_loss 0.7556 | 389s
#   [val] MAE 15.27 | RMSE 28.56 | r 0.308 | n 425
#    per-dataset MAE: {'DLCN': 5.14, 'MCD': 23.69, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 16.41 (n 190)
# epoch 24/30 | train_loss 0.7592 | 386s
#   [val] MAE 14.19 | RMSE 27.24 | r 0.331 | n 425
#    per-dataset MAE: {'DLCN': 3.42, 'MCD': 23.09, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 15.04 (n 190)
#    * new best 14.19
# epoch 25/30 | train_loss 0.7522 | 388s
#   [val] MAE 13.91 | RMSE 27.04 | r 0.308 | n 425
#    per-dataset MAE: {'DLCN': 3.79, 'MCD': 22.28, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 15.02 (n 190)
#    * new best 13.91
# epoch 26/30 | train_loss 0.7469 | 385s
#   [val] MAE 13.70 | RMSE 25.94 | r 0.377 | n 425
#    per-dataset MAE: {'DLCN': 3.49, 'MCD': 22.13, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 13.20 (n 190)
#    * new best 13.7
# epoch 27/30 | train_loss 0.7488 | 384s
#   [val] MAE 13.48 | RMSE 26.06 | r 0.358 | n 425
#    per-dataset MAE: {'DLCN': 3.06, 'MCD': 22.08, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 13.81 (n 190)
#    * new best 13.48
# epoch 28/30 | train_loss 0.7462 | 385s
#   [val] MAE 12.71 | RMSE 24.90 | r 0.392 | n 425
#    per-dataset MAE: {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 12.52 (n 190)
#    * new best 12.71
# epoch 29/30 | train_loss 0.7433 | 388s
#   [val] MAE 13.45 | RMSE 25.71 | r 0.363 | n 425
#    per-dataset MAE: {'DLCN': 3.24, 'MCD': 21.88, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 13.87 (n 190)
# epoch 30/30 | train_loss 0.7458 | 382s
#   [val] MAE 13.01 | RMSE 25.17 | r 0.373 | n 425
#    per-dataset MAE: {'DLCN': 3.12, 'MCD': 21.17, 'UBFC-rPPG': 2.8}
#    resting <90bpm MAE 13.25 (n 190)
# DONE | best val HR MAE: 12.71 (PhysNet baseline was 8.07)

# %% [markdown]
# ## 7. Post-training Evaluation & Bland-Altman

# %%
model.load_state_dict(torch.load('efficientphys_best.pt', map_location=device))
model.eval()

@torch.no_grad()
def collect_predictions(model, loader, waves_per_ds=2):
    rows, waves, wave_ct = [], [], {}
    for batch in loader:
        frames = batch['frames'].to(device, non_blocking=True)
        pred = ep_forward(model, frames).float().cpu().numpy(); bvp = batch['bvp'].numpy()
        hr_true = batch['hr'].numpy(); fps = batch['fps'].numpy(); ds = batch['dataset']
        for i in range(len(pred)):
            if not (40.0 <= hr_true[i] <= 180.0):
                continue
            hp = hr_from_bvp(pred[i], float(fps[i]))
            if not np.isfinite(hp):
                continue
            rows.append((ds[i], float(hr_true[i]), hp))
            if wave_ct.get(ds[i], 0) < waves_per_ds:
                waves.append((ds[i], float(fps[i]), bvp[i].copy(), pred[i].copy()))
                wave_ct[ds[i]] = wave_ct.get(ds[i], 0) + 1
    return pd.DataFrame(rows, columns=['dataset', 'hr_true', 'hr_pred']), waves

pred_df, wave_examples = collect_predictions(model, val_loader)
print('eval clips:', len(pred_df))


def metrics_block(g):
    d = (g['hr_pred'] - g['hr_true']).values
    sd = d.std(ddof=1) if len(d) > 1 else np.nan
    return pd.Series({'n': len(g), 'MAE': np.abs(d).mean(), 'RMSE': np.sqrt((d ** 2).mean()),
                     'bias': d.mean(), 'SD': sd, 'LoA_low': d.mean() - 1.96 * sd,
                     'LoA_high': d.mean() + 1.96 * sd,
                     'Pearson_r': np.corrcoef(g['hr_true'], g['hr_pred'])[0, 1] if len(g) > 2 else np.nan})

summary = pred_df.groupby('dataset').apply(metrics_block, include_groups=False)
overall = metrics_block(pred_df); overall.name = 'ALL'
print(pd.concat([summary, overall.to_frame().T]).round(2).to_string())

colors = {'MCD': 'tab:red', 'DLCN': 'tab:blue', 'UBFC-rPPG': 'tab:green'}
diff = (pred_df.hr_pred - pred_df.hr_true).values
bias, sd = diff.mean(), diff.std(ddof=1)
r = np.corrcoef(pred_df.hr_true, pred_df.hr_pred)[0, 1]
lim = [40, 180]
fig, ax = plt.subplots(1, 3, figsize=(16, 4.8))
for ds, gdf in pred_df.groupby('dataset'):
    ax[0].scatter(gdf.hr_true, gdf.hr_pred, s=12, alpha=0.5, color=colors.get(ds, 'gray'), label=ds)
ax[0].plot(lim, lim, 'k--', lw=1, label='identity')
slope, intc = np.polyfit(pred_df.hr_true, pred_df.hr_pred, 1)
ax[0].plot(np.array(lim), intc + slope * np.array(lim), 'k-', lw=1.2, label=f'fit (slope {slope:.2f})')
ax[0].set(xlim=lim, ylim=lim, xlabel='Reference HR (bpm)', ylabel='Predicted HR (bpm)',
          title=f'Predicted vs reference HR (r = {r:.2f})', aspect='equal')
ax[0].legend(fontsize=8, loc='upper left'); ax[0].grid(alpha=0.3)
for ds, gdf in pred_df.groupby('dataset'):
    m = (gdf.hr_true + gdf.hr_pred) / 2; d = gdf.hr_pred - gdf.hr_true
    ax[1].scatter(m, d, s=12, alpha=0.5, color=colors.get(ds, 'gray'), label=ds)
ax[1].axhline(bias, color='k', lw=1.2, label=f'bias {bias:.1f}')
ax[1].axhline(bias + 1.96 * sd, color='k', ls='--', lw=1, label=f'+1.96SD {bias + 1.96 * sd:.1f}')
ax[1].axhline(bias - 1.96 * sd, color='k', ls='--', lw=1, label=f'-1.96SD {bias - 1.96 * sd:.1f}')
ax[1].set(xlabel='Mean of predicted & reference HR (bpm)', ylabel='Predicted - reference (bpm)', title='Bland-Altman')
ax[1].legend(fontsize=8); ax[1].grid(alpha=0.3)
ax[2].hist(diff, bins=40, color='tab:gray', alpha=0.85, edgecolor='white')
ax[2].axvline(0, color='k', lw=1); ax[2].axvline(bias, color='tab:red', lw=1.3, label=f'bias {bias:.1f}')
ax[2].set(xlabel='Predicted - reference HR (bpm)', ylabel='count',
          title=f'Error distribution (MAE {np.abs(diff).mean():.2f})')
ax[2].legend(fontsize=8); ax[2].grid(alpha=0.3)
plt.tight_layout(); plt.show()

# Waveform overlays: integrate the diff-prediction (cumsum) to a pulse for visual comparison.
fig, axes = plt.subplots(2, 3, figsize=(16, 6))
for k, (ds, fps, bt, bp) in enumerate(wave_examples[:6]):
    axr = axes[k // 3, k % 3]
    bp = np.cumsum(bp - bp.mean())
    bt = (bt - bt.mean()) / (bt.std() + 1e-6); bp = (bp - bp.mean()) / (bp.std() + 1e-6)
    t = np.arange(len(bt)) / fps
    axr.plot(t, bt, color='k', lw=1.0, label='reference')
    axr.plot(t, bp, color='tab:red', lw=1.0, alpha=0.85, label='predicted (integrated)')
    axr.set(title=f'{ds}  (HR ref {hr_from_bvp(bt, fps):.0f} / pred {hr_from_bvp(bp, fps):.0f} bpm)', xlabel='time (s)')
    axr.legend(fontsize=7); axr.grid(alpha=0.3)
plt.tight_layout(); plt.show()
# Out:
# eval clips: 425
#                n    MAE   RMSE  bias     SD  LoA_low  LoA_high  Pearson_r
# DLCN       184.0   2.93  11.25  1.71  11.15   -20.14     23.56       0.79
# MCD        233.0  20.77  32.09 -1.92  32.10   -64.83     61.00       0.23
# UBFC-rPPG    8.0   2.80   5.59 -2.80   5.18   -12.94      7.35       0.91
# ALL        425.0  12.71  24.90 -0.36  24.92   -49.21     48.49       0.39

# %% [markdown]
# ## 8. SQI-gated Re-evaluation
# Re-scores the trained model at increasing reference-BVP SQI thresholds, per dataset, to
# separate model error from reference-label noise. Flat results across thresholds mean the held-out references are clean and the remaining error is genuine model difficulty.

# %%
def clip_sqi(bvp, fps, low=0.7, high=3.5):
    '''3-bin peak-power fraction of the reference BVP = how trustworthy this clip's true-HR label is.'''
    x = np.asarray(bvp, float); x = x - x.mean()
    if x.std() < 1e-8:
        return 0.0
    p = np.abs(np.fft.rfft(x * np.hanning(len(x)))) ** 2
    f = np.fft.rfftfreq(len(x), 1.0 / fps)
    b = (f >= low) & (f <= high)
    if not b.any() or p[b].sum() <= 0:
        return 0.0
    pk = int(np.argmax(p[b]))
    return float(p[b][max(0, pk - 1):pk + 2].sum() / p[b].sum())

FWD = lambda f: ep_forward(model, f)  

@torch.no_grad()
def collect_with_sqi(model, loader, fwd):
    model.eval(); rows = []
    for batch in loader:
        frames = batch['frames'].to(device, non_blocking=True)
        pred = fwd(frames).float().cpu().numpy()      # ty_forward already runs fp32 - no autocast
        bvp = batch['bvp'].numpy(); hr_true = batch['hr'].numpy(); fps = batch['fps'].numpy(); ds = batch['dataset']
        for i in range(len(pred)):
            if not (40.0 <= hr_true[i] <= 180.0):
                continue
            hp = hr_from_bvp(pred[i], float(fps[i]))
            if not np.isfinite(hp):
                continue
            rows.append((ds[i], float(hr_true[i]), hp, clip_sqi(bvp[i], float(fps[i]))))
    return pd.DataFrame(rows, columns=['dataset', 'hr_true', 'hr_pred', 'ref_sqi'])

df = collect_with_sqi(model, val_loader, FWD)
df['ae'] = (df.hr_pred - df.hr_true).abs()
print('total eval clips:', len(df))
for thr in [0.0, 0.05, 0.10, 0.15, 0.20, 0.30]:
    sub = df[df.ref_sqi >= thr]
    if len(sub) < 5:
        continue
    r = np.corrcoef(sub.hr_true, sub.hr_pred)[0, 1] if len(sub) > 2 else float('nan')
    pds = sub.groupby('dataset')['ae'].mean().round(2).to_dict()
    print(f'ref_sqi>={thr:.2f} | n {len(sub):4d} | MAE {sub.ae.mean():5.2f} | r {r:.3f} | per-dataset {pds}')
# Out:
# total eval clips: 425
# ref_sqi>=0.00 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
# ref_sqi>=0.05 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
# ref_sqi>=0.10 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
# ref_sqi>=0.15 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
# ref_sqi>=0.20 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
# ref_sqi>=0.30 | n  425 | MAE 12.71 | r 0.392 | per-dataset {'DLCN': 2.93, 'MCD': 20.77, 'UBFC-rPPG': 2.8}
